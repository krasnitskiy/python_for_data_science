# %% [markdown]
# ### Столбчатая диаграмма среднего уровня дохода игроков некоторых футбольных клубов

# %% [markdown]
# Столбчатая диаграмма позволяет сравнить между собой некоторые (наибролее часто упоминаемые в датасете) футбольные клубы по размеру среднего заработка своих футболистов (что косвенно показывает финансовую состоятельность клубов).

# %%
# импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fp = pd.read_csv('CompleteDataset.csv', low_memory=False) # читаем датасет (создаем датафрейм)

# %%
fp.head() # проверяем, что все корректно прочиталось
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/21.png       92         92
#
#                   Club                                   Club Logo  ...    RB  \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  ...  61.0
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...  57.0
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png  ...  59.0
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...  64.0
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  ...   NaN
#
#     RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 75 columns]

# %%
fp.Wage = fp.Wage.str.strip('€').str.replace('K', '000') # удаляем лишние знаки из столбца дохода

# %%
fp.Wage = fp.Wage.astype(int) # приводим столбец дохода к числовому типу

# %%
wage_club = fp.groupby(['Club'])[['Wage']].mean() # расчитываем средний доход игроков, группируя их по-клубно

# %%
wage_club # проверяем, что все сделали корректно
# Out:
#                                   Wage
# Club
#  SSV Jahn Regensburg       4142.857143
# 1. FC Heidenheim           8153.846154
# 1. FC Kaiserslautern       6275.862069
# 1. FC Köln                25366.666667
# 1. FC Magdeburg            1080.000000
# 1. FC Nürnberg             7214.285714
# 1. FC Union Berlin        16851.851852
# 1. FSV Mainz 05           19566.666667
# AC Ajaccio                 2833.333333
# AC Horsens                 2125.000000
# AD Alcorcón                6160.000000
# ADO Den Haag               6307.692308
# AEK Athens                 1000.000000
# AFC Eskilstuna             1444.444444
# AFC Wimbledon              3518.518519
# AIK Solna                  3833.333333
# AJ Auxerre                 4366.666667
# AS Monaco                 26272.727273
# AS Nancy Lorraine          4192.307692
# AS Saint-Étienne          21433.333333
# AZ Alkmaar                 7111.111111
# Aalborg BK                 3666.666667
# Aalesunds FK               1772.727273
# Aarhus GF                  4296.296296
# Aberdeen                   5291.666667
# Accrington Stanley         2416.666667
# Adelaide United            2500.000000
# Ajax                       9034.482759
# Akhisar Belediyespor      10000.000000
# Al Ahli                   19677.419355
# ...                                ...
# Vitória                    6500.000000
# Vitória Guimarães          7466.666667
# Vitória Setúbal            5259.259259
# Vålerenga Fotball          2038.461538
# Vélez Sarsfield            5178.571429
# Waasland-Beveren           5192.307692
# Walsall                    3714.285714
# Watford                   40093.750000
# Wellington Phoenix         1625.000000
# Werder Bremen II           1000.000000
# West Bromwich Albion      43172.413793
# West Ham United           60468.750000
# Western Sydney Wanderers   3240.000000
# Wigan Athletic             6071.428571
# Willem II                  4857.142857
# Wisła Kraków               3629.629630
# Wisła Płock                2120.000000
# Wolfsberger AC             2720.000000
# Wolverhampton Wanderers   24833.333333
# Wycombe Wanderers          3160.000000
# Würzburger FV              1000.000000
# Yeovil Town                2714.285714
# Yokohama F. Marinos        3000.000000
# Zagłębie Lubin             3259.259259
# Zenit St. Petersburg      45433.333333
# Águilas Doradas            1357.142857
# Örebro SK                  1782.608696
# Östersunds FK              2000.000000
# İstanbul Başakşehir FK    18925.925926
# Śląsk Wrocław              3400.000000
#
# [647 rows x 1 columns]

# %%
fp['Club'].value_counts() # перечень клубов по убыванию числу упоминаний игроков в датасете
# Out:
# Villarreal CF                        35
# UD Las Palmas                        34
# Olympique Lyonnais                   34
# Borussia Dortmund                    34
# OGC Nice                             34
# FC Nantes                            34
# VfL Wolfsburg                        34
# Manchester United                    34
# Bournemouth                          33
# Stoke City                           33
# Hamburger SV                         33
# Arsenal                              33
# Amiens SC Football                   33
# Eintracht Frankfurt                  33
# Crystal Palace                       33
# Málaga CF                            33
# FC Augsburg                          33
# Manchester City                      33
# Hannover 96                          33
# Everton                              33
# ES Troyes AC                         33
# Newcastle United                     33
# Chelsea                              33
# Huddersfield Town                    33
# Southampton                          33
# Brighton & Hove Albion               33
# AS Monaco                            33
# RC Deportivo de La Coruña            33
# Udinese                              32
# West Ham United                      32
#                                      ..
# Santiago Wanderers                   20
# São Paulo Futebol Clube              20
# CD Antofagasta                       20
# CD Palestino                         20
# Vitória                              20
# Everton de Viña del Mar              20
# Associação Atlética Ponte Preta      20
# Club de Deportes Temuco              20
# Associação Chapecoense de Futebol    20
# CD Huachipato                        20
# Deportes Iquique                     20
# Cruzeiro                             20
# Adelaide United                      20
# Atlético Clube Goianiense            20
# Grêmio Foot-Ball Porto Alegrense     20
# Clube Atlético Mineiro               20
# San Luis de Quillota                 20
# Universidad Católica                 20
# Universidad de Chile                 20
# Audax Italiano                       20
# Curicó Unido                         20
# CD O'Higgins                         20
# Santos Futebol Clube                 20
# Botafogo de Futebol e Regatas        20
# Fluminense Football Club             20
# CD Universidad de Concepción         20
# Coritiba Foot Ball Club              20
# Sport Club do Recife                 20
# Sociedade Esportiva Palmeiras        20
# Clube Atlético Paranaense            20
# Name: Club, Length: 647, dtype: int64

# %%
# выводим доход клубов с наибольшим числом игроков в датасете (34 и 35)
wage_club.loc[['VfL Wolfsburg', 
               'VfL Wolfsburg', 
               'UD Las Palmas', 
               'FC Nantes', 
               'Borussia Dortmund', 
               'Manchester United', 
               'OGC Nice', 
               'Olympique Lyonnais']]
# Out:
#                              Wage
# Club
# VfL Wolfsburg        38588.235294
# VfL Wolfsburg        38588.235294
# UD Las Palmas        19441.176471
# FC Nantes            14117.647059
# Borussia Dortmund    50147.058824
# Manchester United   107441.176471
# OGC Nice             23882.352941
# Olympique Lyonnais   32882.352941

# %%
# Строим столбчатую диаграмму
wage_club.loc[['VfL Wolfsburg', 
               'VfL Wolfsburg', 
               'UD Las Palmas', 
               'FC Nantes', 
               'Borussia Dortmund', 
               'Manchester United', 
               'OGC Nice', 
               'Olympique Lyonnais']].plot.bar(colors='green')
